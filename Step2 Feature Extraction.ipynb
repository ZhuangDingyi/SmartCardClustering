# %%
import numpy as np
import pandas as pd
import csv
import time,datetime
from matplotlib import pyplot as plt
from tqdm import tqdm_notebook
import pickle
from sklearn.externals import joblib
from scipy import spatial
# %matplotlib inline

# %%
ds_0319_parser=pd.read_csv('data_processed/20120319 Data1.csv',low_memory=False, iterator=True)
ds_0319_process_parser=pd.read_csv('data_processed/20120319 Data_Merging.csv',low_memory=False, iterator=True)

# %%
chunk1=ds_0319_parser.get_chunk(100)
chunk2=ds_0319_process_parser.get_chunk(100)

# %%
chunk1
# Out:
#       journey_id           card_id passenger_type mode bus_line direction  \
# 0   104342063996  2000029991201000  Child/Student  RTS       \N        \N
# 1   104347264470  2000084766310800  Child/Student  RTS       \N        \N
# 2   104337460089  2000040823741000  Child/Student  RTS       \N        \N
# 3   104348478341  2000110340160800  Child/Student  RTS       \N        \N
# 4   104350771884  2000016576131000  Child/Student  Bus   26             1
# 5   104351959102  2000088565810800  Child/Student  Bus   961            1
# 6   104347364329  2000072167180800  Child/Student  RTS       \N        \N
# 7   104344452279  2000072761190800  Child/Student  Bus   171            1
# 8   104336773003  2000102795490800  Child/Student  Bus   66             0
# 9   104337056371  2000041088141000  Child/Student  Bus   187            0
# 10  104351961874  2000137330830800  Child/Student  Bus   222            1
# 11  104334965299  2000102323320800  Child/Student  RTS       \N        \N
# ...

# %%
chunk2
# Out:
#       journey_id           card_id passenger_type mode_0 bus_line_0  \
# 0   104342063996  2000029991201000  Child/Student    RTS         \N
# 1   104351959102  2000088565810800  Child/Student    Bus     961
# 2   104347364329  2000072167180800  Child/Student    RTS         \N
# 3   104336773003  2000102795490800  Child/Student    Bus     66
# 4   104337056371  2000041088141000  Child/Student    Bus     187
# 5   104351961874  2000137330830800  Child/Student    Bus     222
# 6   104334965299  2000102323320800  Child/Student    RTS         \N
# 7   104342976721  2000021432051000  Child/Student    Bus     178
# 8   104347645352  2000041720101000  Child/Student    Bus     135
# 9   104339462293  2000086008410800  Child/Student    Bus     195
# 10  104350961427  2000054867690800  Child/Student    RTS         \N
# 11  104338276196  1991006890681100  Child/Student    Bus     169
# 12  104346957185  2000083500930800  Child/Student    RTS         \N
# ...
